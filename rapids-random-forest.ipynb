# %%
# %%writefile inference.py

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss

#from tqdm.notebook import tqdm
from tqdm import tqdm

from cuml.ensemble import RandomForestClassifier
from cuml.ensemble import RandomForestRegressor
from cuml import LinearRegression
# Out:
# Writing inference.py

# %% [markdown]
# # Load data

# %%
# %%writefile -a inference.py

train_features = pd.read_csv('../input/lish-moa/train_features.csv')
train_targets = pd.read_csv('../input/lish-moa/train_targets_scored.csv')
test_features = pd.read_csv('../input/lish-moa/test_features.csv')
# Out:
# Appending to inference.py

# %% [markdown]
# # Preprocess data

# %%
# %%writefile -a inference.py


def preprocess_features(df):
    df = df.copy()
    df['cp_dose'] = df['cp_dose'].map({'D1': 0, 'D2': 1})
    df['cp_type'] = df['cp_type'].map({'trt_cp': 0, 'ctl_vehicle': 1})
    df['cp_time'] = df['cp_time'].map({24: 0, 48: 1, 72: 2})
    #df.drop(columns=['sig_id', 'cp_type'], inplace=True)
    del df['sig_id']
    return df
    
train_features = preprocess_features(train_features)
test_features = preprocess_features(test_features)
del train_targets['sig_id']
# Out:
# Appending to inference.py

# %%
# %%writefile -a inference.py


def log_loss_metric(y_true, y_pred):
    metrics = []
    for _target in train_targets.columns:
        metrics.append(log_loss(y_true.loc[:, _target], y_pred.loc[:, _target].astype(float), labels = [0,1]))
    return np.mean(metrics)
# Out:
# Appending to inference.py

# %% [markdown]
# # Train model

# %%
# %%writefile -a inference.py

scaler = StandardScaler()
X = scaler.fit_transform(train_features).astype('float32')
X_test = scaler.transform(test_features).astype('float32')
# Out:
# Appending to inference.py

# %%
# %%writefile -a inference.py


target_columns = train_targets.columns

val_predictions = train_targets.copy()
val_predictions.loc[:, target_columns] = 0

test_predictions = pd.read_csv('../input/lish-moa/sample_submission.csv')
test_predictions.loc[:, target_columns] = 0

SEEDS = 3
FOLDS = 5

for seed in range(SEEDS):
    progress_bar = tqdm(range(train_targets.shape[1]))
    for target_column_idx in progress_bar:

        train_targets_column = train_targets.values[:, target_column_idx]

        if train_targets_column.sum() >= FOLDS: # If target column has less non-zero labels than folds, just skip the column 
            
            skf = StratifiedKFold(n_splits = FOLDS, random_state = seed, shuffle = True)
            for n, (train_idx, val_idx) in enumerate(skf.split(train_targets_column, train_targets_column)):

                X_train, X_val = X[train_idx], X[val_idx]
                y_train, y_val = train_targets_column[train_idx], train_targets_column[val_idx]

                model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
                model.fit(X_train, y_train)

                #val_predictions.loc[val_idx, train_targets.columns[target_column_idx]] += model.predict(X_val) / SEEDS
                #test_predictions.loc[:, train_targets.columns[target_column_idx]] += model.predict(X_test) / (FOLDS*SEEDS)
                val_predictions.loc[val_idx, train_targets.columns[target_column_idx]] += model.predict_proba(X_val)[:, 1] / SEEDS
                test_predictions.loc[:, train_targets.columns[target_column_idx]] += model.predict_proba(X_test)[:, 1] / (FOLDS*SEEDS)


        score = log_loss(train_targets.loc[:, train_targets.columns[target_column_idx]], val_predictions.loc[:, train_targets.columns[target_column_idx]])
        progress_bar.set_description(f"RF Seed: {seed} | column: {target_column_idx+1} | score: {score:.4f} | ")
# Out:
# Appending to inference.py

# %%
# %%writefile -a inference.py


print(f'RFC OOF before postprocessing: {log_loss_metric(train_targets, val_predictions)}')
val_predictions.loc[train_features['cp_type'] == 1, train_targets.columns] = 0
test_predictions.loc[test_features['cp_type'] == 1, train_targets.columns] = 0
print(f'RFC OOF after postprocessing: {log_loss_metric(train_targets, val_predictions)}')
# Out:
# Appending to inference.py

# %%
# %%writefile -a inference.py

cols = [c for c in test_predictions.columns.values if c != 'sig_id'] # todo: do we need this???
X_val_p = val_predictions[cols].values 
X_test_p = test_predictions[cols].values

reg_test_pred = pd.read_csv('../input/lish-moa/sample_submission.csv')
reg_test_pred.loc[:, train_targets.columns] = 0
reg_val_pred = train_targets.copy()
reg_val_pred.loc[:, train_targets.columns] = 0
# Out:
# Appending to inference.py

# %%
# %%writefile -a inference.py

SEEDS = 3
FOLDS = 5

for seed in range(SEEDS):
    progress_bar = tqdm(range(train_targets.shape[1]))
    for target_column_id in progress_bar:
        target_values = train_targets.values[:, target_column_id]

        if target_values.sum() >= FOLDS:
            skf = StratifiedKFold(n_splits = FOLDS, random_state = 42, shuffle = True)
            for n, (train_idx, val_idx) in enumerate(skf.split(target_values, target_values)):

                X_train, X_val = X_val_p[train_idx, target_column_id].reshape(-1, 1), X_val_p[val_idx, target_column_id].reshape(-1, 1)
                y_train, y_val = target_values[train_idx], target_values[val_idx]

                model = LogisticRegression(C = 35, max_iter = 1000, random_state=seed)
                model.fit(X_train, y_train)

                reg_val_pred.loc[val_idx, train_targets.columns[target_column_id]] += model.predict_proba(X_val)[:, 1] / SEEDS
                reg_test_pred.loc[:, train_targets.columns[target_column_id]] += model.predict_proba(X_test_p[:, target_column_id].reshape(-1, 1))[:, 1] / (FOLDS*SEEDS)

        score = log_loss(train_targets.loc[:, train_targets.columns[target_column_id]], reg_val_pred.loc[:, train_targets.columns[target_column_id]])
        progress_bar.set_description(f"LR Seed: {seed} | column: {target_column_idx+1} | score: {score:.4f} | ")
# Out:
# Appending to inference.py

# %%
# %%writefile -a inference.py

print(f'LR OOF before postprocessing: {log_loss_metric(train_targets, reg_val_pred)}')
reg_val_pred.loc[train_features['cp_type'] == 1, train_targets.columns] = 0
reg_test_pred.loc[test_features['cp_type'] == 1, train_targets.columns] = 0
print(f'LR OOF after postprocessing: {log_loss_metric(train_targets, reg_val_pred)}')
# Out:
# Appending to inference.py

# %% [markdown]
# # Create submission file

# %%
# %%writefile -a inference.py
reg_val_pred.to_csv('val-submission.csv', index=False)
reg_test_pred.to_csv('submission.csv', index=False)
# Out:
# Appending to inference.py

# %%
! python inference.py
# Out:
#   0%|                                                   | 0/206 [00:00<?, ?it/s]inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 1 | score: 0.0153 | :   0%| | 1/206 [00:09<32:01,  9.37s/itinference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 2 | score: 0.0266 | :   1%| | 2/206 [00:11<24:52,  7.32s/itinference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 3 | score: 0.0306 | :   1%| | 3/206 [00:14<20:01,  5.92s/itinference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 4 | score: 0.1531 | :   2%| | 4/206 [00:19<18:58,  5.64s/itinference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 5 | score: 0.2241 | :   2%| | 5/206 [00:24<17:58,  5.37s/itinference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 6 | score: 0.0782 | :   3%| | 6/206 [00:27<16:00,  4.80s/itinference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 7 | score: 0.0576 | :   3%| | 7/206 [00:31<14:31,  4.38s/itinference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 8 | score: 0.0948 | :   4%| | 8/206 [00:34<13:48,  4.19s/itinference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 9 | score: 0.0066 | :   4%| | 9/206 [00:37<12:04,  3.68s/itinference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 10 | score: 0.1772 | :   5%| | 10/206 [00:42<13:33,  4.15s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 11 | score: 0.2434 | :   5%| | 11/206 [00:47<14:04,  4.33s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 12 | score: 0.0321 | :   6%| | 12/206 [00:50<12:54,  3.99s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 13 | score: 0.0029 | :   6%| | 13/206 [00:53<11:20,  3.53s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 14 | score: 0.0247 | :   7%| | 14/206 [00:55<10:44,  3.35s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 15 | score: 0.0153 | :   7%| | 15/206 [00:58<09:46,  3.07s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 16 | score: 0.0153 | :   8%| | 16/206 [01:00<09:05,  2.87s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 17 | score: 0.0560 | :   8%| | 17/206 [01:04<09:32,  3.03s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 18 | score: 0.0896 | :   9%| | 18/206 [01:07<10:05,  3.22s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 19 | score: 0.0775 | :   9%| | 19/206 [01:11<10:39,  3.42s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 20 | score: 0.0471 | :  10%| | 20/206 [01:14<10:20,  3.34s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 21 | score: 0.0460 | :  10%| | 21/206 [01:18<10:07,  3.28s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 22 | score: 0.0680 | :  11%| | 22/206 [01:21<10:26,  3.40s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 23 | score: 0.0089 | :  11%| | 23/206 [01:24<09:23,  3.08s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 24 | score: 0.0457 | :  12%| | 24/206 [01:27<09:31,  3.14s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 25 | score: 0.0177 | :  12%| | 25/206 [01:29<08:48,  2.92s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 26 | score: 0.0155 | :  13%|▏| 26/206 [01:32<08:17,  2.77s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 27 | score: 0.0153 | :  13%|▏| 27/206 [01:34<07:55,  2.66s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 28 | score: 0.0218 | :  14%|▏| 28/206 [01:37<08:01,  2.71s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 29 | score: 0.0792 | :  14%|▏| 29/206 [01:40<08:48,  2.99s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 30 | score: 0.0409 | :  15%|▏| 30/206 [01:44<08:54,  3.04s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 31 | score: 0.0242 | :  15%|▏| 31/206 [01:46<08:37,  2.95s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 32 | score: 0.0463 | :  16%|▏| 32/206 [01:50<08:44,  3.02s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 33 | score: 0.0522 | :  16%|▏| 33/206 [01:53<08:44,  3.03s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 35 | score: 0.0015 | :  17%|▏| 34/206 [01:55<07:58,  2.78s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 36 | score: 0.0023 | :  17%|▏| 36/206 [01:57<06:33,  2.31s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 37 | score: 0.0720 | :  18%|▏| 37/206 [02:01<07:37,  2.71s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 38 | score: 0.0094 | :  18%|▏| 38/206 [02:03<07:26,  2.66s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 39 | score: 0.0266 | :  19%|▏| 39/206 [02:07<08:02,  2.89s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 40 | score: 0.0064 | :  19%|▏| 40/206 [02:09<07:34,  2.74s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 41 | score: 0.0690 | :  20%|▏| 41/206 [02:13<08:12,  2.98s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 42 | score: 0.0663 | :  20%|▏| 42/206 [02:16<08:38,  3.16s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 43 | score: 0.0410 | :  21%|▏| 43/206 [02:20<08:40,  3.20s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 44 | score: 0.1602 | :  21%|▏| 44/206 [02:25<10:06,  3.74s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 45 | score: 0.0835 | :  22%|▏| 45/206 [02:28<09:59,  3.73s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 46 | score: 0.1064 | :  22%|▏| 46/206 [02:33<10:17,  3.86s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 47 | score: 0.0016 | :  23%|▏| 47/206 [02:35<08:59,  3.40s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 48 | score: 0.0308 | :  23%|▏| 48/206 [02:38<08:28,  3.22s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 49 | score: 0.0268 | :  24%|▏| 49/206 [02:40<08:07,  3.10s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 50 | score: 0.0718 | :  24%|▏| 50/206 [02:44<08:28,  3.26s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 51 | score: 0.0342 | :  25%|▏| 51/206 [02:47<08:16,  3.20s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 52 | score: 0.0471 | :  25%|▎| 52/206 [02:50<08:07,  3.16s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 53 | score: 0.0282 | :  26%|▎| 53/206 [02:53<07:55,  3.11s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 54 | score: 0.0089 | :  26%|▎| 54/206 [02:55<07:09,  2.82s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 55 | score: 0.2068 | :  27%|▎| 55/206 [03:00<08:30,  3.38s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 56 | score: 0.0497 | :  27%|▎| 56/206 [03:03<08:13,  3.29s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 57 | score: 0.0566 | :  28%|▎| 57/206 [03:06<08:12,  3.30s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 58 | score: 0.0470 | :  28%|▎| 58/206 [03:09<07:49,  3.17s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 59 | score: 0.0347 | :  29%|▎| 59/206 [03:12<07:33,  3.08s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 60 | score: 0.0254 | :  29%|▎| 60/206 [03:15<07:17,  2.99s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 61 | score: 0.0165 | :  30%|▎| 61/206 [03:18<07:25,  3.07s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 62 | score: 0.0950 | :  30%|▎| 62/206 [03:22<07:57,  3.32s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 63 | score: 0.0229 | :  31%|▎| 63/206 [03:25<07:27,  3.13s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 64 | score: 0.0627 | :  31%|▎| 64/206 [03:29<08:11,  3.46s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 65 | score: 0.0565 | :  32%|▎| 65/206 [03:32<07:55,  3.37s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 66 | score: 0.0070 | :  32%|▎| 66/206 [03:35<07:15,  3.11s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 67 | score: 0.0535 | :  33%|▎| 67/206 [03:38<07:17,  3.15s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 68 | score: 0.0611 | :  33%|▎| 68/206 [03:41<07:12,  3.13s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 69 | score: 0.0601 | :  33%|▎| 69/206 [03:44<07:12,  3.16s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 70 | score: 0.0089 | :  34%|▎| 70/206 [03:47<06:31,  2.88s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 71 | score: 0.0200 | :  34%|▎| 71/206 [03:50<06:34,  2.92s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 72 | score: 0.2850 | :  35%|▎| 72/206 [03:55<08:12,  3.67s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 73 | score: 0.0843 | :  35%|▎| 73/206 [03:59<08:21,  3.77s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 74 | score: 0.0297 | :  36%|▎| 74/206 [04:02<07:40,  3.49s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 75 | score: 0.0345 | :  36%|▎| 75/206 [04:05<07:09,  3.28s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 76 | score: 0.0064 | :  37%|▎| 76/206 [04:07<06:26,  2.97s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 77 | score: 0.0426 | :  37%|▎| 77/206 [04:10<06:35,  3.06s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 78 | score: 0.2518 | :  38%|▍| 78/206 [04:15<07:39,  3.59s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 79 | score: 0.1153 | :  38%|▍| 79/206 [04:19<07:56,  3.75s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 80 | score: 0.2448 | :  39%|▍| 80/206 [04:25<09:23,  4.47s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 81 | score: 0.0634 | :  39%|▍| 81/206 [04:30<09:32,  4.58s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 83 | score: 0.0015 | :  40%|▍| 82/206 [04:32<08:07,  3.93s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 84 | score: 0.1224 | :  41%|▍| 84/206 [04:37<06:52,  3.38s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 85 | score: 0.0536 | :  41%|▍| 85/206 [04:40<06:37,  3.28s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 86 | score: 0.0421 | :  42%|▍| 86/206 [04:43<06:28,  3.24s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 87 | score: 0.0103 | :  42%|▍| 87/206 [04:45<05:57,  3.00s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 88 | score: 0.0320 | :  43%|▍| 88/206 [04:48<05:42,  2.90s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 89 | score: 0.0321 | :  43%|▍| 89/206 [04:51<05:43,  2.94s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 90 | score: 0.0580 | :  44%|▍| 90/206 [04:56<07:06,  3.67s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 91 | score: 0.0076 | :  44%|▍| 91/206 [04:59<06:24,  3.35s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 92 | score: 0.0266 | :  45%|▍| 92/206 [05:02<05:54,  3.11s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 93 | score: 0.0242 | :  45%|▍| 93/206 [05:04<05:43,  3.04s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 94 | score: 0.0947 | :  46%|▍| 94/206 [05:08<06:08,  3.29s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 95 | score: 0.1260 | :  46%|▍| 95/206 [05:12<06:33,  3.54s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 96 | score: 0.0294 | :  47%|▍| 96/206 [05:16<06:22,  3.48s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 97 | score: 0.0384 | :  47%|▍| 97/206 [05:20<06:39,  3.66s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 98 | score: 0.0180 | :  48%|▍| 98/206 [05:22<06:01,  3.35s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 99 | score: 0.0772 | :  48%|▍| 99/206 [05:26<06:05,  3.41s/inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 100 | score: 0.2489 | :  49%|▍| 100/206 [05:31<07:07,  4.03inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 101 | score: 0.0254 | :  49%|▍| 101/206 [05:34<06:17,  3.59inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 102 | score: 0.0363 | :  50%|▍| 102/206 [05:37<06:02,  3.48inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 103 | score: 0.0670 | :  50%|▌| 103/206 [05:41<05:57,  3.47inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 104 | score: 0.0352 | :  50%|▌| 104/206 [05:44<05:45,  3.39inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 0 | column: 105 | score: 0.0554 | :  51%|▌| 105/206 [05:47<05:37,  3.34inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# ...
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 173 | score: 0.0080 | :  84%|▊| 173/206 [09:22<01:35,  2.91inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 174 | score: 0.0213 | :  84%|▊| 174/206 [09:25<01:32,  2.90inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 175 | score: 0.0218 | :  85%|▊| 175/206 [09:28<01:28,  2.87inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 176 | score: 0.0258 | :  85%|▊| 176/206 [09:31<01:24,  2.81inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 177 | score: 0.0957 | :  86%|▊| 177/206 [09:36<01:42,  3.54inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 178 | score: 0.1306 | :  86%|▊| 178/206 [09:41<01:48,  3.87inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 179 | score: 0.0363 | :  87%|▊| 179/206 [09:44<01:39,  3.68inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 180 | score: 0.0367 | :  87%|▊| 180/206 [09:47<01:29,  3.45inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 181 | score: 0.0328 | :  88%|▉| 181/206 [09:50<01:21,  3.28inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 182 | score: 0.0196 | :  88%|▉| 182/206 [09:52<01:14,  3.09inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 183 | score: 0.0903 | :  89%|▉| 183/206 [09:57<01:24,  3.69inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 184 | score: 0.0248 | :  89%|▉| 184/206 [10:00<01:16,  3.48inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 185 | score: 0.0287 | :  90%|▉| 185/206 [10:04<01:12,  3.43inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 186 | score: 0.0080 | :  90%|▉| 186/206 [10:06<01:03,  3.17inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 187 | score: 0.0122 | :  91%|▉| 187/206 [10:09<00:59,  3.14inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 188 | score: 0.0430 | :  91%|▉| 188/206 [10:13<00:57,  3.18inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 189 | score: 0.0043 | :  92%|▉| 189/206 [10:15<00:50,  2.97inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 190 | score: 0.0193 | :  92%|▉| 190/206 [10:18<00:46,  2.93inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 191 | score: 0.0249 | :  93%|▉| 191/206 [10:21<00:43,  2.91inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 192 | score: 0.0311 | :  93%|▉| 192/206 [10:23<00:40,  2.87inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 193 | score: 0.0107 | :  94%|▉| 193/206 [10:26<00:35,  2.75inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 194 | score: 0.0277 | :  94%|▉| 194/206 [10:29<00:34,  2.87inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 195 | score: 0.0303 | :  95%|▉| 195/206 [10:33<00:33,  3.07inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 196 | score: 0.0239 | :  95%|▉| 196/206 [10:35<00:29,  2.92inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 197 | score: 0.0092 | :  96%|▉| 197/206 [10:37<00:24,  2.71inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 198 | score: 0.0155 | :  96%|▉| 198/206 [10:41<00:22,  2.87inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 199 | score: 0.0412 | :  97%|▉| 199/206 [10:44<00:20,  2.94inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 200 | score: 0.0434 | :  97%|▉| 200/206 [10:48<00:20,  3.34inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 201 | score: 0.0380 | :  98%|▉| 201/206 [10:52<00:17,  3.46inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 202 | score: 0.0080 | :  98%|▉| 202/206 [10:54<00:12,  3.09inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 203 | score: 0.0391 | :  99%|▉| 203/206 [10:58<00:10,  3.43inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 204 | score: 0.0276 | :  99%|▉| 204/206 [11:02<00:06,  3.44inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 205 | score: 0.0137 | : 100%|▉| 205/206 [11:05<00:03,  3.27inference.py:74: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams==1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=seed, verbose=2)
# RF Seed: 2 | column: 206 | score: 0.0323 | : 100%|█| 206/206 [11:08<00:00,  3.24
# RFC OOF before postprocessing: 0.03380021450742051
# RFC OOF after postprocessing: 0.03343527543060762
# LR Seed: 0 | column: 206 | score: 0.0102 | : 100%|█| 206/206 [00:42<00:00,  4.79
# LR Seed: 1 | column: 206 | score: 0.0098 | : 100%|█| 206/206 [00:39<00:00,  5.17
# LR Seed: 2 | column: 206 | score: 0.0097 | : 100%|█| 206/206 [00:39<00:00,  5.21
# LR OOF before postprocessing: 0.016768542054045387
# LR OOF after postprocessing: 0.01657875903161154
