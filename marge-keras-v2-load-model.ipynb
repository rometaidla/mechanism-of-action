# %%
# %%writefile inference.py
import sys
sys.path.append('../input/iterative-stratification/iterative-stratification-master')
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold

# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# Writing inference.py

# %%
# %%writefile -a inference.py


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
import tensorflow_addons as tfa
from tensorflow.keras.layers import Input, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras import layers,regularizers,Sequential,backend,callbacks,optimizers,metrics,losses
from keras.models import Sequential
from tqdm import tqdm
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.metrics import log_loss





from sklearn import preprocessing
from sklearn.decomposition import PCA

print(keras.__version__)
print(tf.__version__)
# Out:
# Appending to inference.py

# %%
# %%writefile -a inference.py
train_features = pd.read_csv('../input/lish-moa/train_features.csv')
train_targets = pd.read_csv('../input/lish-moa/train_targets_scored.csv')
test_features = pd.read_csv('../input/lish-moa/test_features.csv')
# Out:
# Appending to inference.py

# %% [markdown]
# # Preprocess data

# %%
# %%writefile -a inference.py
def preprocess_features(df):
    df = df.copy()
    
    df['cp_dose'] = df['cp_dose'].map({'D1': 0, 'D2': 1})
    df['cp_time'] = df['cp_time'].map({24: 0, 48: 1, 72: 2})
    df.drop(columns=['sig_id', 'cp_type'], inplace=True)
    df.drop(['g-219', 'g-307', 'g-104', 'g-550', 'g-331','g-15','g-481','g-435','g-536','g-661'],axis=1, inplace=True)

    return df
    
train_features = preprocess_features(train_features)
test_features = preprocess_features(test_features)
train_targets.drop(columns=['sig_id'], inplace=True)
# Out:
# Appending to inference.py

# %%
# %%writefile -a inference.py
def create_training_graphs(training_history):
    plt.figure(figsize=(16, 6))

    plt.subplot(1, 2, 1)
    plt.plot(training_history.history['loss'])
    plt.plot(training_history.history['val_loss'])
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss')

    plt.subplot(1, 2, 2)
    plt.plot(training_history.history['accuracy'])
    plt.plot(training_history.history['val_accuracy'])
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(['Training', 'Validation'])
    plt.title('Accuracy')
# Out:
# Appending to inference.py

# %%
# %%writefile -a inference.py

def create_model(input_size):
    model = keras.Sequential([
        Dense(2048, input_shape=(input_size,), activation="relu", name="input"),
        Dropout(rate=0.5),
        BatchNormalization(),
        Dense(1024, activation="relu", name="dense1"),
        Dropout(rate=0.5),
        BatchNormalization(),
        Dense(206, activation="sigmoid", name="output")
    ])
    
    #optimizer = tf.keras.optimizers.Adam(lr=0.001)

    #model.compile(loss=tf.keras.losses.BinaryCrossentropy(label_smoothing=0.1), optimizer=optimizer, metrics=['accuracy'])
    model.compile(optimizer=tfa.optimizers.Lookahead(tf.optimizers.Adam(), sync_period=10),
                  loss=losses.BinaryCrossentropy(label_smoothing=0.001),metrics=['accuracy'])

    return model


#model.compile(loss='binary_crossentropy', optimizer=optimizer, label_smoothing=0.001, metrics=['accuracy'])
# Out:
# Appending to inference.py

# %% [markdown]
# # Train

# %%
# %%writefile -a inference.py

def log_loss_metric(y_true, y_pred):
    metrics = []
    for _target in train_targets.columns:
        metrics.append(log_loss(y_true.loc[:, _target], y_pred.loc[:, _target].astype(float), labels = [0,1]))
    return np.mean(metrics)
# Out:
# Appending to inference.py

# %%
# %%writefile -a inference.py

#early_stopping = tf.keras.callbacks.EarlyStopping(
    #monitor="val_loss",
    #min_delta=0,
    #patience=10,
    #verbose=1,
    #mode="auto",
    #baseline=None,
    #restore_best_weights=True)


early_stopping = EarlyStopping(monitor="val_loss", min_delta=0, patience=10, verbose=1, mode="auto", baseline=None, restore_best_weights=True)
reduce_lr_loss = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1, epsilon=1e-4, mode='min')
# Out:
# Appending to inference.py

# %%
# %%writefile -a inference.py
#model = create_model(len(train_features.columns))
#history = model.fit(train_features, train_targets, batch_size=64, epochs=500, validation_split=0.1, callbacks=[early_stopping])

histories = []

target_columns = train_targets.columns

val_predictions = train_targets.copy()
val_predictions.loc[:, target_columns] = 0

test_predictions = pd.read_csv('../input/lish-moa/sample_submission.csv')
test_predictions.loc[:, target_columns] = 0

SEEDS = 3
SPLITS = 5
MAX_EPOCHS = 500
BATCH_SIZE = 64

progress_bar = tqdm(range(SEEDS))
for seed in progress_bar:
    mskf = MultilabelStratifiedKFold(n_splits=SPLITS, random_state=seed, shuffle=True)
    for fold_idx, (train_idx, val_idx) in enumerate(mskf.split(X=train_features, y=train_targets)):
        X_train, X_val = train_features.loc[train_idx], train_features.loc[val_idx]
        y_train, y_val = train_targets.loc[train_idx], train_targets.loc[val_idx]

        model = create_model(len(train_features.columns))
        history = model.fit(X_train, y_train, batch_size=BATCH_SIZE, epochs=MAX_EPOCHS, validation_data=(X_val, y_val), callbacks=[early_stopping, reduce_lr_loss])
        histories.append(history)

        val_predictions.loc[val_idx, train_targets.columns] +=  model.predict(X_val) / SEEDS
        test_predictions.loc[:, target_columns] += model.predict(test_features) / (SPLITS * SEEDS)
# Out:
# Appending to inference.py

# %%
#%%writefile -a inference.py
#create_training_graphs(history)

# %% [markdown]
# # Predictions

# %%
#%%writefile -a inference.py
#predictions = model.predict(test_features)

# %% [markdown]
# # Create submission

# %%
#import joblib
#loaded_model = joblib.load('../input/marge-keras-v2.sav')

# %%
# %%writefile -a inference.py
#test_features1 = pd.read_csv('../input/lish-moa/test_features.csv')
#submission = pd.DataFrame({'sig_id': test_features1['sig_id'].values})

train_features1 = pd.read_csv('../input/lish-moa/train_features.csv')
test_features1 = pd.read_csv('../input/lish-moa/test_features.csv')

print(f'NN OOF before postprocessing: {log_loss_metric(train_targets, val_predictions):.6f}')
val_predictions.loc[train_features1['cp_type'] == 'ctl_vehicle', train_targets.columns] = 0
test_predictions.loc[test_features1['cp_type'] == 'ctl_vehicle', train_targets.columns] = 0
print(f'NN OOF after postprocessing: {log_loss_metric(train_targets, val_predictions):.6f}')
# Out:
# Appending to inference.py

# %%
#%%writefile -a inference.py
#for col in train_targets.columns.to_list():
    #submission[col] = 0

#submission.loc[:, train_targets.columns] = predictions

# %%
#%%writefile inference.py
# Set control drug prediction to 0
#submission.loc[submission['sig_id'].isin(test_features1.loc[test_features1['cp_type'] == 'ctl_vehicle', 'sig_id']), train_targets.columns] = 0

# %%
# %%writefile -a inference.py

#submission.to_csv('submission.csv', index=False)

val_predictions.to_csv('val-submission.csv', index=False)
test_predictions.to_csv('submission.csv', index=False)
# Out:
# Appending to inference.py

# %%
! python inference.py
# Out:
# /kaggle/input/lish-moa/train_features.csv
# /kaggle/input/lish-moa/train_drug.csv
# /kaggle/input/lish-moa/test_features.csv
# /kaggle/input/lish-moa/train_targets_nonscored.csv
# /kaggle/input/lish-moa/sample_submission.csv
# /kaggle/input/lish-moa/train_targets_scored.csv
# /kaggle/input/marge-keras-v2/__results__.html
# /kaggle/input/marge-keras-v2/submission.csv
# /kaggle/input/marge-keras-v2/custom.css
# /kaggle/input/marge-keras-v2/__notebook__.ipynb
# /kaggle/input/marge-keras-v2/__output__.json
# /kaggle/input/marge-keras-v2/__results___files/__results___14_0.png
# /kaggle/input/iterative-stratification/iterative-stratification-master/.gitignore
# /kaggle/input/iterative-stratification/iterative-stratification-master/LICENSE
# /kaggle/input/iterative-stratification/iterative-stratification-master/setup.py
# /kaggle/input/iterative-stratification/iterative-stratification-master/setup.cfg
# /kaggle/input/iterative-stratification/iterative-stratification-master/.travis.yml
# /kaggle/input/iterative-stratification/iterative-stratification-master/README.md
# /kaggle/input/iterative-stratification/iterative-stratification-master/tests/__init__.py
# /kaggle/input/iterative-stratification/iterative-stratification-master/tests/test_ml_stratifiers.py
# /kaggle/input/iterative-stratification/iterative-stratification-master/iterstrat/ml_stratifiers.py
# /kaggle/input/iterative-stratification/iterative-stratification-master/iterstrat/__init__.py
# 2020-11-30 07:32:46.930097: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.2
# 2020-11-30 07:32:47.187909: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.2
# 2.4.0
# 2.3.1
#   0%|                                                     | 0/3 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass shuffle=True, random_state=0 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
# 2020-11-30 07:33:01.064932: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-11-30 07:33:01.407523: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-30 07:33:01.408400: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-11-30 07:33:01.408485: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.2
# 2020-11-30 07:33:01.509705: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-11-30 07:33:01.576476: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-11-30 07:33:01.590721: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-11-30 07:33:01.693348: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-11-30 07:33:01.706461: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-11-30 07:33:01.890210: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-11-30 07:33:01.890540: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-30 07:33:01.891415: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-30 07:33:01.892041: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-11-30 07:33:01.892406: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX512F
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-11-30 07:33:01.915522: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2000175000 Hz
# 2020-11-30 07:33:01.915773: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x557ce40370a0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 07:33:01.915943: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-11-30 07:33:01.917562: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-30 07:33:01.919042: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-11-30 07:33:01.919138: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.2
# 2020-11-30 07:33:01.919193: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-11-30 07:33:01.919225: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-11-30 07:33:01.919256: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-11-30 07:33:01.919296: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-11-30 07:33:01.919356: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-11-30 07:33:01.919400: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-11-30 07:33:01.919505: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-30 07:33:01.920243: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-30 07:33:01.920921: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-11-30 07:33:03.315898: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-11-30 07:33:03.315959: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-11-30 07:33:03.316038: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-11-30 07:33:03.319053: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-30 07:33:03.319993: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-30 07:33:03.320804: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-30 07:33:03.321523: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14960 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# 2020-11-30 07:33:03.328765: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x557cfe1cad00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 07:33:03.328800: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# Epoch 1/500
# 2020-11-30 07:33:06.089094: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 298/298 [==============================] - 2s 7ms/step - loss: 0.2801 - accuracy: 0.0217 - val_loss: 0.0310 - val_accuracy: 0.0456
# Epoch 2/500
# 298/298 [==============================] - 2s 7ms/step - loss: 0.0280 - accuracy: 0.0570 - val_loss: 0.0228 - val_accuracy: 0.0636
# Epoch 3/500
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0241 - accuracy: 0.0751 - val_loss: 0.0221 - val_accuracy: 0.0771
# Epoch 4/500
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0230 - accuracy: 0
500
# 298/298 [==============================] - 2s 7ms/step - loss: 0.0241 - accuracy: 0.0698 - val_loss: 0.0219 - val_accuracy: 0.0754
# Epoch 4/500
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0229 - accuracy: 0.0858 - val_loss: 0.0213 - val_accuracy: 0.0859
# Epoch 5/500
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0222 - accuracy: 0.0954 - val_loss: 0.0209 - val_accuracy: 0.0918
# Epoch 6/500
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0215 - accuracy: 0.1004 - val_loss: 0.0204 - val_accuracy: 0.0953
# Epoch 7/500
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0212 - accuracy: 0.1063 - val_loss: 0.0205 - val_accuracy: 0.0945
# Epoch 8/500
# 298/298 [==============================] - 2s 7ms/step - loss: 0.0209 - accuracy: 0.1098 - val_loss: 0.0203 - val_accuracy: 0.0993
# Epoch 9/500
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0206 - accuracy: 0.1154 - val_loss: 0.0202 - val_accuracy: 0.1046
# Epoch 10/500
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0203 - accuracy: 0.1223 - val_loss: 0.0199 - val_accuracy: 0.1081
# Epoch 11/500
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0200 - accuracy: 0.1260 - val_loss: 0.0197 - val_accuracy: 0.1176
# Epoch 12/500
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0197 - accuracy: 0.1318 - val_loss: 0.0195 - val_accuracy: 0.1201
# Epoch 13/500
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0194 - accuracy: 0.1370 - val_loss: 0.0196 - val_accuracy: 0.1180
# Epoch 14/500
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0190 - accuracy: 0.1488 - val_loss: 0.0194 - val_accuracy: 0.1231
# Epoch 15/500
# 298/298 [==============================] - 2s 8ms/step - loss: 0.0186 - accuracy: 0.1550 - val_loss: 0.0193 - val_accuracy: 0.1281
# Epoch 16/500
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0182 - accuracy: 0.1625 - val_loss: 0.0194 - val_accuracy: 0.1268
# Epoch 17/500
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0178 - accuracy: 0.1727 - val_loss: 0.0193 - val_accuracy: 0.1283
# Epoch 18/500
# 296/298 [============================>.] - ETA: 0s - loss: 0.0173 - accuracy: 0.1888
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0174 - accuracy: 0.1885 - val_loss: 0.0195 - val_accuracy: 0.1331
# Epoch 19/500
# 298/298 [==============================] - 2s 7ms/step - loss: 0.0165 - accuracy: 0.2075 - val_loss: 0.0191 - val_accuracy: 0.1327
# Epoch 20/500
# 298/298 [==============================] - 2s 8ms/step - loss: 0.0162 - accuracy: 0.2135 - val_loss: 0.0190 - val_accuracy: 0.1361
# Epoch 21/500
# 298/298 [==============================] - 2s 7ms/step - loss: 0.0161 - accuracy: 0.2216 - val_loss: 0.0190 - val_accuracy: 0.1373
# Epoch 22/500
# 293/298 [============================>.] - ETA: 0s - loss: 0.0159 - accuracy: 0.2215
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 298/298 [==============================] - 2s 7ms/step - loss: 0.0159 - accuracy: 0.2214 - val_loss: 0.0190 - val_accuracy: 0.1373
# Epoch 23/500
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0158 - accuracy: 0.2288 - val_loss: 0.0190 - val_accuracy: 0.1375
# Epoch 24/500
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0158 - accuracy: 0.2275 - val_loss: 0.0190 - val_accuracy: 0.1373
# Epoch 25/500
# 298/298 [==============================] - ETA: 0s - loss: 0.0157 - accuracy: 0.2293
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0157 - accuracy: 0.2293 - val_loss: 0.0190 - val_accuracy: 0.1373
# Epoch 26/500
# 298/298 [==============================] - 2s 7ms/step - loss: 0.0157 - accuracy: 0.2269 - val_loss: 0.0190 - val_accuracy: 0.1378
# Epoch 27/500
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0157 - accuracy: 0.2301 - val_loss: 0.0190 - val_accuracy: 0.1373
# Epoch 28/500
# 297/298 [============================>.] - ETA: 0s - loss: 0.0158 - accuracy: 0.2309
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 298/298 [==============================] - 2s 6ms/step - loss: 0.0158 - accuracy: 0.2308 - val_loss: 0.0190 - val_accuracy: 0.1378
# Epoch 29/500
# 298/298 [==============================] - 2s 7ms/step - loss: 0.0157 - accuracy: 0.2317 - val_loss: 0.0190 - val_accuracy: 0.1373
# Epoch 30/500
# 298/298 [==============================] - 2s 7ms/step - loss: 0.0157 - accuracy: 0.2279 - val_loss: 0.0190 - val_accuracy: 0.1380
# Epoch 31/500
# 293/298 [============================>.] - ETA: 0s - loss: 0.0157 - accuracy: 0.2285
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 298/298 [==============================] - 2s 7ms/step - loss: 0.0157 - accuracy: 0.2286 - val_loss: 0.0190 - val_accuracy: 0.1378
# Epoch 32/500
# 294/298 [============================>.] - ETA: 0s - loss: 0.0157 - accuracy: 0.2292Restoring model weights from the end of the best epoch.
# 298/298 [==============================] - 2s 8ms/step - loss: 0.0157 - accuracy: 0.2290 - val_loss: 0.0190 - val_accuracy: 0.1378
# Epoch 00032: early stopping
# 100%|████████████████████████████████████████████| 3/3 [16:01<00:00, 320.49s/it]
# NN OOF before postprocessing: 0.015076
# NN OOF after postprocessing: 0.014927
